# %%
import psycopg2 
import pandas as pd
import numpy as np
import math
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
from skforecast.ForecasterAutoreg import ForecasterAutoreg

# %%
conn = psycopg2.connect(
    host="fit3164db.cxkhqsoitzhb.ap-southeast-2.rds.amazonaws.com", 
    port=5432,
    user="postgres",
    password="fit3164d13edas",
    database = "testdb"
)
conn.autocommit = True
cursor = conn.cursor()

# %%
#actuals columns
cursor.execute("SELECT column_name FROM information_schema.columns WHERE table_name = 'actuals'")
acc_cols = cursor.fetchall()
acc_cols = [item[0] for item in acc_cols]
print(acc_cols)
# Out:
# ['id', 'datetime', 'load', 'pressure', 'cloud_cover', 'humidity', 'temperature', 'wind_speed', 'wind_direction', 'date', 'month', 'hour', 'type_of_day', 'covid', 'holiday']

# %%
cursor.execute("select * from actuals")
actual_data = cursor.fetchall()

# %%
#forecasts columns
cursor.execute("SELECT column_name FROM information_schema.columns WHERE table_name = 'forecasts'")
fc_cols = cursor.fetchall()
fc_cols = [item[0] for item in fc_cols]
print(fc_cols)
# Out:
# ['id', 'datetime', 'pressure', 'cloud_cover', 'temperature', 'wind_speed', 'wind_direction', 'date', 'month', 'hour', 'type_of_day', 'covid', 'holiday']

# %%
cursor.execute("select * from forecasts")
forecast_data = cursor.fetchall()

# %%
cursor.close()
conn.close()

# %%
actuals = pd.DataFrame(actual_data, columns= acc_cols)
forecast = pd.DataFrame(forecast_data, columns=fc_cols)

# %%
# converting data types:
def convert_dtypes(df, actual=True):
    if actual:
        numeric_cols = ['month','hour', 'type_of_day','covid', 'holiday', 'load', 'pressure', 'cloud_cover', 'humidity', 'temperature', 'wind_speed', 'wind_direction']
    else:
        numeric_cols = ['month','hour', 'type_of_day','covid', 'holiday', 'pressure', 'cloud_cover', 'temperature', 'wind_speed', 'wind_direction']
    
    date_cols = ['datetime', 'date']
    
    for col in numeric_cols:
        df[col] = pd.to_numeric(df[col])
        
    for col in date_cols:
        df[col] = pd.to_datetime(df[col])
    
    return df
actuals = convert_dtypes(actuals)
forecast = convert_dtypes(forecast, False)

# %%
def calculate_mae(actual, predicted):
    return mean_absolute_error(actual, predicted)

def calculate_mape(actual, predicted):
    a = actual.to_numpy()
    p = predicted.to_numpy()

    return np.mean(np.abs((a - p) / a)) * 100

def calculate_rmse(actual, predicted):
    return math.sqrt(mean_squared_error(actual, predicted))

def get_error_measures(actual, predicted):
    result = "MAE: " + str(calculate_mae(actual, predicted)) + "\n"
    result += "MAPE: " + str(calculate_mape(actual, predicted)) + "\n"
    result += "RMSE: " + str(calculate_rmse(actual, predicted)) + "\n"
    return result

# %%
def encode(data, col, max_val):
    data[col + '_sin'] = np.sin(2 * np.pi * data[col]/max_val)
    data[col + '_cos'] = np.cos(2 * np.pi * data[col]/max_val)
    return data

# %%
#lags for load 

def get_lag_leads(data, num_lags=168, forward_pred=48): 
    
    cols = ['pressure', 'cloud_cover', 'temperature', 'wind_speed',
       'wind_direction']

    #for load
    for i in range(1, num_lags + 1):    #gonna start from 2 bc need min 1 for skforecast
        data[f'load_lag_{i}'] = data['load'].shift(i) 

    #for lagged weather variables
    for c in cols:
        for i in range(1, num_lags+1):
            data[f'{c}_lag_{i}'] = data[c].shift(i)
        
    #for 48h forecasted weather ?
    # for c in cols: 
    #     for f in range(1, forward_pred + 1):    #lead 48 variables
    #         data[f'{c}_lead_{f}'] = data[c].shift(-f)

    data.dropna(inplace = True)    #drop nulls
    data = data.set_index('datetime')   #set index as datetime
    data = data.asfreq('H')

    return data

# %%
errors_df = pd.DataFrame(columns = ["start_date", "end_date", "mae", "mape", "rmse"])

# %%
data = pd.merge(actuals[['datetime','load']], forecast, on='datetime')
# data = data.rename(columns = {'datetime': 'ds','load': 'y'})

encode(data, 'hour', 24)
encode(data, 'month', 12)
encode(data, 'type_of_day', 31)

data = data.drop(['id', 'date', 'covid', 'holiday','month', 'hour', 'type_of_day'], axis=1)
data = data.rename(columns = {'type_of_day_sin': 'day_sin', 
                            'type_of_day_cos': 'day_cos'})

# %%
data.columns
# Out:
# Index(['datetime', 'load', 'pressure', 'cloud_cover', 'temperature',
#        'wind_speed', 'wind_direction', 'hour_sin', 'hour_cos', 'month_sin',
#        'month_cos', 'day_sin', 'day_cos'],
#       dtype='object')

# %% [markdown]
# If we use lags=50, we won't be starting at 00:00:00, we will be starting at 02:00:00

# %%
data.head()
# Out:
#              datetime          load  pressure  cloud_cover  temperature  \
# 0 2017-03-18 00:00:00  1.031472e+06    1011.0          3.0         14.0
# 1 2017-03-18 01:00:00  1.007206e+06    1011.0          4.0         14.0
# 2 2017-03-18 02:00:00  9.861084e+05    1011.0          4.0         14.0
# 3 2017-03-18 03:00:00  9.707610e+05    1011.0          4.0         14.0
# 4 2017-03-18 04:00:00  9.622584e+05    1011.0          4.0         14.0
#
#    wind_speed  wind_direction  hour_sin  hour_cos  month_sin     month_cos  \
# 0         2.0           307.0  0.000000  1.000000        1.0  6.123234e-17
# 1         2.0           215.0  0.258819  0.965926        1.0  6.123234e-17
# 2         1.0           123.0  0.500000  0.866025        1.0  6.123234e-17
# 3         1.0            31.0  0.707107  0.707107        1.0  6.123234e-17
# 4         1.0           138.0  0.866025  0.500000        1.0  6.123234e-17
#
#     day_sin   day_cos
# 0  0.937752  0.347305
# 1  0.937752  0.347305
# 2  0.937752  0.347305
# 3  0.937752  0.347305
# 4  0.937752  0.347305

# %%
data = get_lag_leads(data)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'load_lag_{i}'] = data['load'].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\3072313938.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[f'{c}_lag_{i}'] = data[c].shift(i)

# %%
data.columns[:50]
# Out:
# Index(['load', 'pressure', 'cloud_cover', 'temperature', 'wind_speed',
#        'wind_direction', 'hour_sin', 'hour_cos', 'month_sin', 'month_cos',
#        'day_sin', 'day_cos', 'load_lag_1', 'load_lag_2', 'load_lag_3',
#        'load_lag_4', 'load_lag_5', 'load_lag_6', 'load_lag_7', 'load_lag_8',
#        'load_lag_9', 'load_lag_10', 'load_lag_11', 'load_lag_12',
#        'load_lag_13', 'load_lag_14', 'load_lag_15', 'load_lag_16',
#        'load_lag_17', 'load_lag_18', 'load_lag_19', 'load_lag_20',
#        'load_lag_21', 'load_lag_22', 'load_lag_23', 'load_lag_24',
#        'load_lag_25', 'load_lag_26', 'load_lag_27', 'load_lag_28',
#        'load_lag_29', 'load_lag_30', 'load_lag_31', 'load_lag_32',
#        'load_lag_33', 'load_lag_34', 'load_lag_35', 'load_lag_36',
#        'load_lag_37', 'load_lag_38'],
#       dtype='object')

# %%
import xgboost as xgb

# %%
exog = data.drop('load', axis=1)
target = data['load']

# %%
#idg the point of splitting into train and valid actually but sure lol
train_size = 30089
train_features, test_features = exog[:train_size], exog[train_size:train_size+12]
train_target, test_target = target[:train_size], target[train_size:train_size+12]

# %%
#recursive multi-step forecasting 
#==============================================================================
horizon = 48 #predict 48 hours

#this the model
model = xgb.XGBRegressor()  

def sliding_window(data, model=xgb.XGBRegressor(), horizon=48, slide_by=24, window_size=96):      
    
    first_timestep = 0
    last_timestep = window_size

    data_features = data.drop(['load'], axis=1)
    data_target = data['load']

    mae = []
    mape = []
    rmse = []

    windows = 0

    while last_timestep <= data.shape[0]:

        windows += 1
        
        #current window forecast features
        #over whole data? or over training only?
        window_train_exog = data_features.iloc[first_timestep: last_timestep]
        window_train_target = data_target.iloc[first_timestep: last_timestep]

        print(f'Fitting window {windows}...')
        model.fit(window_train_exog, window_train_target)

        window_mae = 0
        window_mape = 0
        window_rmse = 0
        
        
        #multi-step forecasting for the next 48 hours
        #create a table to store the forecasted values
        s = first_timestep + window_size
        l = s + horizon
        forecasted_values = pd.Series(data=np.zeros(horizon), index=data.iloc[s:l].index)

        for i in range(horizon):
            
            pred_start = first_timestep + window_size + i
            pred_end = pred_start + horizon + i

            #one time point
            forecast_features = data_features.iloc[pred_start: pred_start+1]

            #predict
            forecast = model.predict(forecast_features)

            #record the forecasted values
            forecasted_values[i] = forecast[0]

            #update the lag values with the predicted lag
            for lag in range(168,1,-1):
                forecast_features[f'load_lag_{lag}'] = forecast_features[f'load_lag_{lag-1}']
            forecast_features['load_lag_1'] = forecast 


        start_index = first_timestep + window_size
        end_index = start_index + horizon
        forecast_actuals = data_target.iloc[start_index:end_index]

        #error calculate
        window_mae += calculate_mae(forecast_actuals, forecasted_values)
        window_mape += calculate_mape(forecast_actuals, forecasted_values)
        window_rmse += calculate_rmse(forecast_actuals, forecasted_values)
            

        mae.append(window_mae/horizon)
        mape.append(window_mape/horizon)
        rmse.append(window_rmse/horizon)


        first_timestep += slide_by
        last_timestep += slide_by

        error_metrics = {}
        error_metrics['mae'] = mae
        error_metrics['mape'] = mape
        error_metrics['rmse'] = rmse

    return error_metrics

# %%
exog.head()
# Out:
#                      pressure  cloud_cover  temperature  wind_speed  \
# datetime
# 2017-03-25 00:00:00    1010.0          0.0          8.0        10.0
# 2017-03-25 01:00:00    1010.0          0.0          8.0        10.0
# 2017-03-25 02:00:00    1010.0          0.0          8.0         9.0
# 2017-03-25 03:00:00    1010.0          0.0          8.0         9.0
# 2017-03-25 04:00:00    1011.0          0.0         10.0        10.0
#
#                      wind_direction  hour_sin  hour_cos  month_sin  \
# datetime
# 2017-03-25 00:00:00           328.0  0.000000  1.000000        1.0
# 2017-03-25 01:00:00           219.0  0.258819  0.965926        1.0
# 2017-03-25 02:00:00           111.0  0.500000  0.866025        1.0
# 2017-03-25 03:00:00             2.0  0.707107  0.707107        1.0
# 2017-03-25 04:00:00             4.0  0.866025  0.500000        1.0
#
#                         month_cos   day_sin  ...  wind_direction_lag_159  \
# datetime                                     ...
# 2017-03-25 00:00:00  6.123234e-17  0.937752  ...                   256.0
# 2017-03-25 01:00:00  6.123234e-17  0.937752  ...                   263.0
# 2017-03-25 02:00:00  6.123234e-17  0.937752  ...                   271.0
# 2017-03-25 03:00:00  6.123234e-17  0.937752  ...                   278.0
# 2017-03-25 04:00:00  6.123234e-17  0.937752  ...                   280.0
#
#                      wind_direction_lag_160  wind_direction_lag_161  \
# datetime
# 2017-03-25 00:00:00                   288.0                   320.0
# 2017-03-25 01:00:00                   256.0                   288.0
# 2017-03-25 02:00:00                   263.0                   256.0
# 2017-03-25 03:00:00                   271.0                   263.0
# 2017-03-25 04:00:00                   278.0                   271.0
#
#                      wind_direction_lag_162  wind_direction_lag_163  \
# datetime
# 2017-03-25 00:00:00                   352.0                   245.0
# 2017-03-25 01:00:00                   320.0                   352.0
# 2017-03-25 02:00:00                   288.0                   320.0
# 2017-03-25 03:00:00                   256.0                   288.0
# 2017-03-25 04:00:00                   263.0                   256.0
#
#                      wind_direction_lag_164  wind_direction_lag_165  \
# datetime
# 2017-03-25 00:00:00                   138.0                    31.0
# 2017-03-25 01:00:00                   245.0                   138.0
# 2017-03-25 02:00:00                   352.0                   245.0
# 2017-03-25 03:00:00                   320.0                   352.0
# 2017-03-25 04:00:00                   288.0                   320.0
#
#                      wind_direction_lag_166  wind_direction_lag_167  \
# datetime
# 2017-03-25 00:00:00                   123.0                   215.0
# 2017-03-25 01:00:00                    31.0                   123.0
# 2017-03-25 02:00:00                   138.0                    31.0
# 2017-03-25 03:00:00                   245.0                   138.0
# 2017-03-25 04:00:00                   352.0                   245.0
#
#                      wind_direction_lag_168
# datetime
# 2017-03-25 00:00:00                   307.0
# 2017-03-25 01:00:00                   215.0
# 2017-03-25 02:00:00                   123.0
# 2017-03-25 03:00:00                    31.0
# 2017-03-25 04:00:00                   138.0
#
# [5 rows x 1019 columns]

# %%
exog.loc['2017-03-25 00:00:00', 'pressure'] = exog.loc['2017-03-25 01:00:00', 'wind_speed']

# %%
exog.head()
# Out:
#                      pressure  cloud_cover  temperature  wind_speed  \
# datetime
# 2017-03-25 00:00:00      10.0          0.0          8.0        10.0
# 2017-03-25 01:00:00    1010.0          0.0          8.0        10.0
# 2017-03-25 02:00:00    1010.0          0.0          8.0         9.0
# 2017-03-25 03:00:00    1010.0          0.0          8.0         9.0
# 2017-03-25 04:00:00    1011.0          0.0         10.0        10.0
#
#                      wind_direction  hour_sin  hour_cos  month_sin  \
# datetime
# 2017-03-25 00:00:00           328.0  0.000000  1.000000        1.0
# 2017-03-25 01:00:00           219.0  0.258819  0.965926        1.0
# 2017-03-25 02:00:00           111.0  0.500000  0.866025        1.0
# 2017-03-25 03:00:00             2.0  0.707107  0.707107        1.0
# 2017-03-25 04:00:00             4.0  0.866025  0.500000        1.0
#
#                         month_cos   day_sin  ...  wind_direction_lag_159  \
# datetime                                     ...
# 2017-03-25 00:00:00  6.123234e-17  0.937752  ...                   256.0
# 2017-03-25 01:00:00  6.123234e-17  0.937752  ...                   263.0
# 2017-03-25 02:00:00  6.123234e-17  0.937752  ...                   271.0
# 2017-03-25 03:00:00  6.123234e-17  0.937752  ...                   278.0
# 2017-03-25 04:00:00  6.123234e-17  0.937752  ...                   280.0
#
#                      wind_direction_lag_160  wind_direction_lag_161  \
# datetime
# 2017-03-25 00:00:00                   288.0                   320.0
# 2017-03-25 01:00:00                   256.0                   288.0
# 2017-03-25 02:00:00                   263.0                   256.0
# 2017-03-25 03:00:00                   271.0                   263.0
# 2017-03-25 04:00:00                   278.0                   271.0
#
#                      wind_direction_lag_162  wind_direction_lag_163  \
# datetime
# 2017-03-25 00:00:00                   352.0                   245.0
# 2017-03-25 01:00:00                   320.0                   352.0
# 2017-03-25 02:00:00                   288.0                   320.0
# 2017-03-25 03:00:00                   256.0                   288.0
# 2017-03-25 04:00:00                   263.0                   256.0
#
#                      wind_direction_lag_164  wind_direction_lag_165  \
# datetime
# 2017-03-25 00:00:00                   138.0                    31.0
# 2017-03-25 01:00:00                   245.0                   138.0
# 2017-03-25 02:00:00                   352.0                   245.0
# 2017-03-25 03:00:00                   320.0                   352.0
# 2017-03-25 04:00:00                   288.0                   320.0
#
#                      wind_direction_lag_166  wind_direction_lag_167  \
# datetime
# 2017-03-25 00:00:00                   123.0                   215.0
# 2017-03-25 01:00:00                    31.0                   123.0
# 2017-03-25 02:00:00                   138.0                    31.0
# 2017-03-25 03:00:00                   245.0                   138.0
# 2017-03-25 04:00:00                   352.0                   245.0
#
#                      wind_direction_lag_168
# datetime
# 2017-03-25 00:00:00                   307.0
# 2017-03-25 01:00:00                   215.0
# 2017-03-25 02:00:00                   123.0
# 2017-03-25 03:00:00                    31.0
# 2017-03-25 04:00:00                   138.0
#
# [5 rows x 1019 columns]

# %%
errors = sliding_window(data)
# Out:
# Fitting window 1...
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features[f'load_lag_{lag}'] = forecast_features[f'load_lag_{lag-1}']
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features['load_lag_1'] = forecast
# Fitting window 2...
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features[f'load_lag_{lag}'] = forecast_features[f'load_lag_{lag-1}']
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features['load_lag_1'] = forecast
# Fitting window 3...
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features[f'load_lag_{lag}'] = forecast_features[f'load_lag_{lag-1}']
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features['load_lag_1'] = forecast
# Fitting window 4...
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features[f'load_lag_{lag}'] = forecast_features[f'load_lag_{lag-1}']
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features['load_lag_1'] = forecast
# Fitting window 5...
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features[f'load_lag_{lag}'] = forecast_features[f'load_lag_{lag-1}']
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features['load_lag_1'] = forecast
# Fitting window 6...
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features[f'load_lag_{lag}'] = forecast_features[f'load_lag_{lag-1}']
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features['load_lag_1'] = forecast
# Fitting window 7...
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features[f'load_lag_{lag}'] = forecast_features[f'load_lag_{lag-1}']
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features['load_lag_1'] = forecast
# Fitting window 8...
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features[f'load_lag_{lag}'] = forecast_features[f'load_lag_{lag-1}']
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features['load_lag_1'] = forecast
# Fitting window 9...
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features[f'load_lag_{lag}'] = forecast_features[f'load_lag_{lag-1}']
# C:\Users\danie\AppData\Local\Temp\ipykernel_11036\844988700.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_features['load_lag_1'] = forecast
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\danie\OneDrive\Desktop\Monash\FIT3163\xgboost_multi_2.ipynb Cell 25 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/danie/OneDrive/Desktop/Monash/FIT3163/xgboost_multi_2.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> a, v = sliding_window(data)
#
# c:\Users\danie\OneDrive\Desktop\Monash\FIT3163\xgboost_multi_2.ipynb Cell 25 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/danie/OneDrive/Desktop/Monash/FIT3163/xgboost_multi_2.ipynb#X34sZmlsZQ%3D%3D?line=50'>51</a> forecast_features = data_features.iloc[pred_start: pred_start+1]
#      <a href='vscode-notebook-cell:/c%3A/Users/danie/OneDrive/Desktop/Monash/FIT3163/xgboost_multi_2.ipynb#X34sZmlsZQ%3D%3D?line=52'>53</a> #predict
# ---> <a href='vscode-notebook-cell:/c%3A/Users/danie/OneDrive/Desktop/Monash/FIT3163/xgboost_multi_2.ipynb#X34sZmlsZQ%3D%3D?line=53'>54</a> forecast = model.predict(forecast_features)
#      <a href='vscode-notebook-cell:/c%3A/Users/danie/OneDrive/Desktop/Monash/FIT3163/xgboost_multi_2.ipynb#X34sZmlsZQ%3D%3D?line=55'>56</a> #record the forecasted values
#      <a href='vscode-notebook-cell:/c%3A/Users/danie/OneDrive/Desktop/Monash/FIT3163/xgboost_multi_2.ipynb#X34sZmlsZQ%3D%3D?line=56'>57</a> forecasted_values[i] = forecast[0]
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\sklearn.py:1114, in XGBModel.predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#    1112 if self._can_use_inplace_predict():
#    1113     try:
# -> 1114         predts = self.get_booster().inplace_predict(
#    1115             data=X,
#    1116             iteration_range=iteration_range,
#    1117             predict_type="margin" if output_margin else "value",
#    1118             missing=self.missing,
#    1119             base_margin=base_margin,
#    1120             validate_features=validate_features,
#    1121         )
#    1122         if _is_cupy_array(predts):
#    1123             import cupy  # pylint: disable=import-error
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:2284, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2282 enable_categorical = _has_categorical(self, data)
#    2283 if _is_pandas_df(data):
# -> 2284     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#    2285     if validate_features:
#    2286         self._validate_features(fns)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\data.py:397, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta, meta_type)
#     391     _invalid_dataframe_dtype(data)
#     393 feature_names, feature_types = _pandas_feature_info(
#     394     data, meta, feature_names, feature_types, enable_categorical
#     395 )
# --> 397 transformed = _pandas_cat_null(data)
#     399 if meta and len(data.columns) > 1 and meta not in _matrix_meta:
#     400     raise ValueError(f"DataFrame for {meta} cannot have multiple columns")
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\data.py:347, in _pandas_cat_null(data)
#     341 # handle category codes and nullable.
#     342 cat_columns = [
#     343     col
#     344     for col, dtype in zip(data.columns, data.dtypes)
#     345     if is_categorical_dtype(dtype)
#     346 ]
# --> 347 nul_columns = [
#     348     col for col, dtype in zip(data.columns, data.dtypes) if is_nullable_dtype(dtype)
#     349 ]
#     350 if cat_columns or nul_columns:
#     351     # Avoid transformation due to: PerformanceWarning: DataFrame is highly
#     352     # fragmented
#     353     transformed = data.copy()
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\data.py:348, in <listcomp>(.0)
#     341 # handle category codes and nullable.
#     342 cat_columns = [
#     343     col
#     344     for col, dtype in zip(data.columns, data.dtypes)
#     345     if is_categorical_dtype(dtype)
#     346 ]
#     347 nul_columns = [
# --> 348     col for col, dtype in zip(data.columns, data.dtypes) if is_nullable_dtype(dtype)
#     349 ]
#     350 if cat_columns or nul_columns:
#     351     # Avoid transformation due to: PerformanceWarning: DataFrame is highly
#     352     # fragmented
#     353     transformed = data.copy()
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\data.py:335, in is_nullable_dtype(dtype)
#     333 # np.bool has alias `bool`, while pd.BooleanDtype has `bzoolean`.
#     334 is_bool = is_bool_dtype(dtype) and dtype.name == "boolean"
# --> 335 is_float = is_float_dtype(dtype) and dtype.name in nullable_alias
#     336 return is_int or is_bool or is_float or is_categorical_dtype(dtype)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\common.py:1275, in is_float_dtype(arr_or_dtype)
#    1246 def is_float_dtype(arr_or_dtype) -> bool:
#    1247     """
#    1248     Check whether the provided array or dtype is of a float dtype.
#    1249
#    (...)
#    1273     True
#    1274     """
# -> 1275     return _is_dtype_type(arr_or_dtype, classes(np.floating))
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\common.py:1610, in _is_dtype_type(arr_or_dtype, condition)
#    1608 # fastpath
#    1609 if isinstance(arr_or_dtype, np.dtype):
# -> 1610     return condition(arr_or_dtype.type)
#    1611 elif isinstance(arr_or_dtype, type):
#    1612     if issubclass(arr_or_dtype, ExtensionDtype):
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\common.py:148, in classes.<locals>.<lambda>(tipo)
#     146 def classes(*klasses) -> Callable:
#     147     """Evaluate if the tipo is a subclass of the klasses."""
# --> 148     return lambda tipo: issubclass(tipo, klasses)
#
# KeyboardInterrupt:

# %% [markdown]
# Multi-Step Forecasting:
#
# To make multi-step forecasts, you need to implement a forecasting loop that iteratively predicts each future time point within the forecast horizon. The general steps within this loop include:
# - Provide the model with input features for the current time step.
# - Use the model to predict the value for the current time step.
# - Update the input features for the next time step by incorporating the actual value just predicted (autoregressive approach).
# - Repeat these steps for each time step within the forecast horizon

# %% [markdown]
# model.predict(x) \
# x should include:
# - lagged loads
# - lagged weather data
# - lead weather data
