# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from actuals_inp_handling import ActualsHandler

# %% [markdown]
# Testing with data gap

# %%
file1 = "./ErrorTestingFiles/data_gap_a.csv"

handler = ActualsHandler()
handler.handle_upload_actuals([file1])
# Out:
# File(s) Received.
# A few outliers were detected which were dealt with.
# Saved into the database.

# %% [markdown]
# Testing with duplicates

# %%
file1 = "./ErrorTestingFiles/duplicates_a.csv"

handler = ActualsHandler()
handler.handle_upload_actuals([file1])
# Out:
# File(s) Received.
# Duplicates were detected in the given file.
# Duplicates were detected in the given file.
# A few outliers were detected which were dealt with.
# Saved into the database.

# %% [markdown]
# Testing with invalid data types

# %%
file1 = "./ErrorTestingFiles/invaliddatatype.csv"

handler = ActualsHandler()
handler.handle_upload_actuals([file1])
# Out:
# File(s) Received.
# Error converting 'datetime' to datetime64[ns]

# %% [markdown]
# Testing with no column names

# %%
file1 = "./ErrorTestingFiles/nocolumnnames.csv"

handler = ActualsHandler()
handler.handle_upload_actuals([file1])
# Out:
# File(s) Received.
# Please provide a file with the correct column names.

# %% [markdown]
# Testing with wrong column names

# %%
file1 = "./ErrorTestingFiles/wrongcolnames.csv"

handler = ActualsHandler()
handler.handle_upload_actuals([file1])
# Out:
# File(s) Received.
# Please provide a file with the correct column names.

# %% [markdown]
# Testing with missing values

# %%
file1 = "./ErrorTestingFiles/missingcells.csv"

handler = ActualsHandler()
handler.handle_upload_actuals([file1])
# Out:
# File(s) Received.
# File contains missing values. A few outliers were detected which were dealt with.
# Saved into the database.

# %% [markdown]
# Testing with incomplete data

# %%
file1 = "./ErrorTestingFiles/missingvalues.csv"

handler = ActualsHandler()
handler.handle_upload_actuals([file1])
# Out:
# File(s) Received.
# A few outliers were detected which were dealt with.
# Saved into the database.

# %% [markdown]
# Testing with outliers

# %%
file1 = "./ErrorTestingFiles/outliers.csv"

handler = ActualsHandler()
handler.handle_upload_actuals([file1])
# Out:
# File(s) Received.
# A few outliers were detected which were dealt with.
# Saved into the database.

# %%
from forecast_inp_handling import ForecastsHandler

# %% [markdown]
# Testing with data gap

# %%
file1 = "./ErrorTestingFiles/data_gap_p.csv"

handler = ForecastsHandler()
handler.handle_predict_demand([file1])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/siddharthjadli/Monash/2023Sem2/FIT3164/myfiles/ElectricityDemandForecasterProject/usr_inp_error_handling.ipynb Cell 22 line 4
#       <a href='vscode-notebook-cell:/Users/siddharthjadli/Monash/2023Sem2/FIT3164/myfiles/ElectricityDemandForecasterProject/usr_inp_error_handling.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> file1 = "./ErrorTestingFiles/data_gap_p.csv"
#       <a href='vscode-notebook-cell:/Users/siddharthjadli/Monash/2023Sem2/FIT3164/myfiles/ElectricityDemandForecasterProject/usr_inp_error_handling.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a> handler = ForecastsHandler()
# ----> <a href='vscode-notebook-cell:/Users/siddharthjadli/Monash/2023Sem2/FIT3164/myfiles/ElectricityDemandForecasterProject/usr_inp_error_handling.ipynb#X30sZmlsZQ%3D%3D?line=3'>4</a> handler.handle_predict_demand([file1])
#
# ...

# %% [markdown]
# Testing with duplicates

# %%
file1 = "./ErrorTestingFiles/duplicates_p.xlsx"

handler = ForecastsHandler()
handler.handle_predict_demand([file1])
# Out:
# File(s) Received.
# File submitted contains some missing rows, which have been appropriately dealt with.Missing values were detected in the file which were dealt with.Duplicates were detected in the given file.
#
# WARNING: You have not submitted actual values for previous days before 2021-01-21 08:00:00.
# Solution implemented is to make predictions for the missing days and use them as the actual values.
# As a result, the prediction accuracy may be negatively impacted.
# A few outliers were detected which were dealt with.
# Making predictions
#                datetime  pressure  cloud_cover  temperature  wind_direction  \
# 0   2021-01-15 08:00:00    1013.0          0.0    13.721890           263.0
# 1   2021-01-15 09:00:00    1013.0          0.0    13.721890           263.0
# 2   2021-01-15 10:00:00    1013.0          0.0    13.721890           263.0
# 3   2021-01-15 11:00:00    1013.0          0.0    13.721890           263.0
# ...

# %% [markdown]
# Testing with invalid data types

# %%
file1 = "./ErrorTestingFiles/invaliddatatype.csv"

handler = ForecastsHandler()
handler.handle_predict_demand([file1])
# Out:
# File(s) Received.
# Error converting 'datetime' to datetime64[ns]

# %% [markdown]
# Testing with no column names

# %%
file1 = "./ErrorTestingFiles/nocolumnnames.csv"

handler = ForecastsHandler()
handler.handle_predict_demand([file1])
# Out:
# File(s) Received.
# Please provide a file with the correct column names

# %% [markdown]
# Testing with wrong column names

# %%
file1 = "./ErrorTestingFiles/wrongcolnames.csv"

handler = ForecastsHandler()
handler.handle_predict_demand([file1])
# Out:
# File(s) Received.
# Please provide a file with the correct column names

# %% [markdown]
# Testing with missing values

# %%
file1 = "./ErrorTestingFiles/missingcells_p.csv"

handler = ForecastsHandler()
handler.handle_predict_demand([file1])
# Out:
# File(s) Received.
# Missing values were detected in the file which were dealt with.
# WARNING: You have not submitted actual values for previous days before 2021-01-17 08:00:00.
# Solution implemented is to make predictions for the missing days and use them as the actual values.
# As a result, the prediction accuracy may be negatively impacted.
# A few outliers were detected which were dealt with.
# Making predictions
#               datetime  pressure  cloud_cover  temperature  wind_direction  \
# 0  2021-01-15 08:00:00    1013.0          0.0    11.721890           270.0
# 1  2021-01-15 09:00:00    1013.0          0.0    11.721890           270.0
# 2  2021-01-15 10:00:00    1013.0          0.0    11.721890           270.0
# 3  2021-01-15 11:00:00    1013.0          0.0    11.721890           270.0
# 4  2021-01-15 12:00:00    1013.0          0.0    11.721890           270.0
# ..                 ...       ...          ...          ...             ...
# ...

# %% [markdown]
# Testing with incomplete data

# %%
file1 = "./ErrorTestingFiles/missingvalues_p.csv"

handler = ForecastsHandler()
handler.handle_predict_demand([file1])
# Out:
# Please provide 2 days' worth of data (48 hours).

# %% [markdown]
# Testing with outliers

# %%
file1 = "./ErrorTestingFiles/outliers_p.xlsx"

handler = ForecastsHandler()
handler.handle_predict_demand([file1])
# Out:
# File(s) Received.
# A few outliers were detected which were dealt with.
# Making predictions
#      pressure  cloud_cover  temperature  wind_direction  wind_speed  \
# 0   1014.5250        0.000     4.391886          61.625     3.34375
# 1   1014.9625        5.875     8.371886          73.750     7.34250
# 2   1015.1000        3.625    15.274386         111.250     5.75375
# 3   1014.8250        0.000    19.241886          34.375     9.34250
# 4   1013.9875        0.125    23.509386          59.750     9.83750
# 5   1012.8500        0.000    22.506886         274.375    10.46000
# 6   1012.0375        0.000    20.624386         269.625    19.00375
# 7   1011.5125        0.875    19.866886         280.000    22.47500
# 8   1011.3125        1.500    19.679386         299.750    19.69750
# 9   1011.4250        0.125    16.481886         300.000    18.13875
# 10  1012.1750        0.000    13.941886         322.375    13.93000
# ...
